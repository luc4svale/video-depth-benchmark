# %% [markdown]
# # 01 — Prepare TUM RGB-D data
#
# Run this only if `data/processed/` is empty or you want to regenerate it
# from scratch. This repository already ships the prepared TUM videos,
# ground-truth depth, and RGB-depth pairing files, so notebooks 02, 03 and 04
# reuse the same data instead of rebuilding it each time.
#
# Downloads the raw TUM RGB-D sequences, pairs RGB and depth frames by
# timestamp, encodes RGB frames into an H.264 video without B-frames, and
# saves the ground-truth depth as a compressed `.npz`.

# %% [markdown]
# > **Running on Google Colab instead of locally?** The cell below clones
# > this repository into the Colab VM automatically (skipped if you're
# > running locally, where the repo is already on disk). Everything after
# > that works the same either way.

# %%
# Only runs if this notebook is executing on Google Colab
IN_COLAB = "google.colab" in str(get_ipython())
if IN_COLAB:
    # !git clone https://github.com/luc4svale/video-depth-benchmark.git
    # %cd video-depth-benchmark

# %%
import os

# If running on VSCode/Jupyter with the working directory already at the
# repo root, this is a no-op. If the notebook's default cwd is notebooks/, 
# this steps back up one level.
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

REPO_ROOT = os.getcwd()
assert os.path.exists(os.path.join(REPO_ROOT, "scripts")), (
    "Could not find scripts/ from the current working directory. "
    "cd into your cloned copy of this repository before running this notebook."
)
print("Repo root:", REPO_ROOT)
# Out:
# Repo root: /home/luc4svale/code/playground/video-depth-benchmark

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -r requirements.txt -q
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Run the preparation script
#
# This step calls `ffmpeg` directly. If it fails with `FileNotFoundError: ffmpeg`,
# install it (`sudo apt install ffmpeg` on Ubuntu/Debian, `brew install ffmpeg`
# on macOS) and re-run.

# %%
# !python scripts/prepare_tum_videos.py \
    --raw_dir /tmp/tum_raw \
    --tmp_dir /tmp/tum_frames_tmp \
    --output_dir data/processed
# Out:
# [skip] already extracted: /tmp/tum_raw/rgbd_dataset_freiburg1_desk
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
# ...

# %% [markdown]
# ## Verify outputs
#
# You should now have 9 files in `data/processed/`: 3 `.mp4`, 3 `_gt_depth.npz`, and 3 `tum_pairs_*.json`.

# %%
# !ls -la data/processed/
# Out:
# total 28568
# drwxr-xr-x 2 luc4svale luc4svale    4096 jul  8 12:08 .
# drwxr-xr-x 4 luc4svale luc4svale    4096 jul  8 10:14 ..
# -rw-rw-r-- 1 luc4svale luc4svale 9322459 jul  8 11:44 tum_freiburg1_desk_gt_depth.npz
# -rw-rw-r-- 1 luc4svale luc4svale 1726898 jul  8 11:44 tum_freiburg1_desk.mp4
# -rw-rw-r-- 1 luc4svale luc4svale 7875247 jul  8 12:01 tum_freiburg2_desk_gt_depth.npz
# -rw-rw-r-- 1 luc4svale luc4svale 1954406 jul  8 12:01 tum_freiburg2_desk.mp4
# -rw-rw-r-- 1 luc4svale luc4svale 7190188 jul  8 12:08 tum_freiburg3_office_gt_depth.npz
# -rw-rw-r-- 1 luc4svale luc4svale 1141923 jul  8 12:08 tum_freiburg3_office.mp4
# -rw-rw-r-- 1 luc4svale luc4svale    6820 jul  8 11:44 tum_pairs_fr1.json
# -rw-rw-r-- 1 luc4svale luc4svale    6820 jul  8 12:01 tum_pairs_fr2.json
# -rw-rw-r-- 1 luc4svale luc4svale    6820 jul  8 12:08 tum_pairs_fr3.json
